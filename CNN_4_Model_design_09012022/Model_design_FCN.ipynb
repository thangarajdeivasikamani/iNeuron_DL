# %% [markdown]
# #### Objetive of the Task reduce the Trainable param 14,000 & accuracy is above 99%"

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils

# %%
mnist=tf.keras.datasets.mnist

# %%
(x_train_full,y_train_full),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
(x_train,x_valid)=x_train_full[5000:],x_train_full[:5000]
(y_train,y_valid)=y_train_full[5000:],y_train_full[:5000]

# %%
x_train.shape
# Out:
# (55000, 28, 28)

# %%
num_classes=len(np.unique(y_train))


y_train=np_utils.to_categorical(y_train,num_classes)

y_test=np_utils.to_categorical(y_test,num_classes)
y_valid=np_utils.to_categorical(y_valid,num_classes)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

from keras.layers import BatchNormalization,Dropout, Activation

# %%
model5=Sequential()

model5.add(Conv2D(filters=8,kernel_size=3,activation='LeakyReLU',input_shape=(28,28,1))) #input - Kernal+1 => 26*26*8
model5.add(BatchNormalization())


model5.add(Conv2D(filters=8,kernel_size=3,activation='LeakyReLU')) #24*24*8
model5.add(BatchNormalization())


model5.add(Conv2D(filters=8,kernel_size=3,activation='LeakyReLU'))
model5.add(BatchNormalization())
model5.add(Dropout(0.2))


model5.add(Conv2D(filters=10,kernel_size=3,activation='LeakyReLU'))
model5.add(BatchNormalization())
model5.add(Dropout(0.1))

model5.add(Conv2D(filters=16,kernel_size=3,activation='LeakyReLU'))
model5.add(BatchNormalization())

model5.add(MaxPooling2D(pool_size=2))


model5.add(Conv2D(filters=16,kernel_size=3,activation='LeakyReLU'))
model5.add(BatchNormalization())

model5.add(Conv2D(filters=10,kernel_size=3,activation='LeakyReLU'))
model5.add(BatchNormalization())
model5.add(Dropout(0.2))

model5.add(Conv2D(filters=10,kernel_size=5,activation='LeakyReLU'))


model5.add(Flatten())

model5.add(Activation('softmax'))

model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 8)         80
#
#  batch_normalization (BatchN  (None, 26, 26, 8)        32
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 8)         584
#
#  batch_normalization_1 (Batc  (None, 24, 24, 8)        32
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 22, 22, 8)         584
#
#  batch_normalization_2 (Batc  (None, 22, 22, 8)        32
#  hNormalization)
#
#  dropout (Dropout)           (None, 22, 22, 8)         0
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 10)        730
#
#  batch_normalization_3 (Batc  (None, 20, 20, 10)       40
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 20, 20, 10)        0
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 16)        1456
#
#  batch_normalization_4 (Batc  (None, 18, 18, 16)       64
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 9, 9, 16)         0
#  )
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 16)          2320
#
#  batch_normalization_5 (Batc  (None, 7, 7, 16)         64
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 10)          1450
#
#  batch_normalization_6 (Batc  (None, 5, 5, 10)         40
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 5, 5, 10)          0
#
#  conv2d_7 (Conv2D)           (None, 1, 1, 10)          2510
#
#  flatten (Flatten)           (None, 10)                0
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 10,018
# Trainable params: 9,866
# Non-trainable params: 152
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model5.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
#from keras.callbacks import ModelCheckpoint,EarlyStopping,LearningRateScheduler
EPOCHS=10
VALIDATION_DATA=(x_valid,y_valid)

model5.fit(x_train,y_train,epochs=EPOCHS,validation_data=VALIDATION_DATA)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 130s 75ms/step - loss: 0.2168 - accuracy: 0.9329 - val_loss: 0.0861 - val_accuracy: 0.9754
# Epoch 2/10
# 1719/1719 [==============================] - 135s 79ms/step - loss: 0.0828 - accuracy: 0.9742 - val_loss: 0.0572 - val_accuracy: 0.9826
# Epoch 3/10
# 1719/1719 [==============================] - 133s 77ms/step - loss: 0.0672 - accuracy: 0.9792 - val_loss: 0.0514 - val_accuracy: 0.9852
# Epoch 4/10
# 1719/1719 [==============================] - 133s 77ms/step - loss: 0.0608 - accuracy: 0.9814 - val_loss: 0.0453 - val_accuracy: 0.9860
# Epoch 5/10
# 1719/1719 [==============================] - 129s 75ms/step - loss: 0.0542 - accuracy: 0.9825 - val_loss: 0.0411 - val_accuracy: 0.9884
# Epoch 6/10
# 1719/1719 [==============================] - 128s 75ms/step - loss: 0.0522 - accuracy: 0.9843 - val_loss: 0.0389 - val_accuracy: 0.9890
# Epoch 7/10
# 1719/1719 [==============================] - 129s 75ms/step - loss: 0.0490 - accuracy: 0.9848 - val_loss: 0.0443 - val_accuracy: 0.9894
# Epoch 8/10
# 1719/1719 [==============================] - 128s 75ms/step - loss: 0.0466 - accuracy: 0.9851 - val_loss: 0.0416 - val_accuracy: 0.9896
# Epoch 9/10
# 1719/1719 [==============================] - 131s 76ms/step - loss: 0.0436 - accuracy: 0.9869 - val_loss: 0.0403 - val_accuracy: 0.9876
# Epoch 10/10
# 1719/1719 [==============================] - 130s 75ms/step - loss: 0.0426 - accuracy: 0.9867 - val_loss: 0.0376 - val_accuracy: 0.9892
